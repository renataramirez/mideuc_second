# %% [markdown]
# # ORTOGRAFÍA ACENTUAL

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()
API_KEY = os.getenv("AZURE_OPENAI_KEY")
ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
DEPLOYMENT_GPT = os.getenv("AZURE_OPENAI_DEPLOYMENT_GPT")
API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

client = AzureOpenAI(
    api_key=API_KEY,
    api_version=API_VERSION,
    azure_endpoint=ENDPOINT
)

df = pd.read_excel("escritos_seleccionados_ort.xlsx")
textos = df["escrito"].dropna().tolist() 

prompt_acentual = """
Eres un asistente experto en corrección de textos.

EVALÚA Y CORRIGE EXCLUSIVAMENTE los errores en el texto relacionados con el uso de tildes en español. 
Considera las reglas generales (palabras agudas, graves, esdrújulas y sobreesdrújulas) 
y las reglas especiales (acento diacrítico y acento dierético).

Tu respuesta debe seguir exactamente esta estructura:

{
  "errores_acentuales": {
        "error_1": ["error → corrección"],
        "error_2": ["error → corrección"],
        "error_3": ["error → corrección"],
        ...
  }
}

INSTRUCCIONES CRÍTICAS:
- SOLO reporta errores en los que la diferencia entre error y corrección sea la presencia o ausencia de una tilde.
- NO señales problemas de ortografía, puntuación, vocabulario ni otros aspectos.
- NO incluyas el texto corregido completo.
- NO uses markdown, NO incluyas ```json, devuelve SOLO el JSON.
"""

resultados = []

for i, texto in enumerate(textos, start=1):
    print(f"Procesando texto {i}/{len(textos)}...")

    messages = [
        {"role": "system", "content": prompt_acentual},
        {"role": "user", "content": texto}
    ]

    try:
        response = client.chat.completions.create(
            model=DEPLOYMENT_GPT,
            messages=messages,
            temperature=0,
            response_format={"type": "json_object"}
        )

        respuesta_limpia = response.choices[0].message.content.strip()
        resultado_json = json.loads(respuesta_limpia)
        resultados.append({
            "id_texto": i,
            "resultado": resultado_json
        })

    except json.JSONDecodeError as e:
        print(f"Error al parsear JSON en texto {i}: {e}")
        print("Respuesta cruda recibida:")
        print(respuesta_limpia)

output_path = os.path.join("correcciones_selectas", "acentuales.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(resultados, f, ensure_ascii=False, indent=4)

print(f"\nTodos los resultados guardados en {output_path}")
# Out:
# Procesando texto 1/10...
# Procesando texto 2/10...
# Procesando texto 3/10...
# Procesando texto 4/10...
# Procesando texto 5/10...
# Procesando texto 6/10...
# Procesando texto 7/10...
# Procesando texto 8/10...
# Procesando texto 9/10...
# Procesando texto 10/10...
#
# Todos los resultados guardados en correcciones_selectas\acentual.json

# %% [markdown]
# # ORTOGRAFÍA LITERAL

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()
API_KEY = os.getenv("AZURE_OPENAI_KEY")
ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
DEPLOYMENT_GPT = os.getenv("AZURE_OPENAI_DEPLOYMENT_GPT")
API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

client = AzureOpenAI(
    api_key=API_KEY,
    api_version=API_VERSION,
    azure_endpoint=ENDPOINT
)

df = pd.read_excel("escritos_seleccionados_ort.xlsx")
textos = df["escrito"].dropna().tolist() 

prompt_literal = """
Eres un asistente experto en corrección de textos. 

Corrige ÚNICAMENTE los siguientes tipos de errores:

1. Mayúsculas ausentes: inicio de párrafo, tras punto, nombres propios. Ej: ". ahora" → ". Ahora", "madrid" → "Madrid".
2. Omisión de letras: ej. "alchol" → "alcohol", "gerra" → "guerra", "aora" → "ahora".
3. Sustitución de letras: ej. "girafa" → "jirafa", "obeja" → "oveja".
4. Adición de letras: ej. "rrallado" → "rallado", "exhuberante" → "exuberante". Incluye "en carro": ej. “apartir” → “a partir”, “através” → “a través”.

INSTRUCCIÓN CRÍTICA:
- NO revises ni corrijas tildes (acentos ortográficos). 
- Cualquier palabra cuya única diferencia con la forma correcta sea la presencia o ausencia de una tilde DEBE SER IGNORADA.
- Si la única “corrección” que encuentras sería añadir o quitar una tilde, NO la reportes.

Formato de respuesta OBLIGATORIO (solo JSON válido):

{
  "errores_ortografia_literal": {
        "error_1": ["error → corrección"],
        "error_2": ["error → corrección"],
        ...
  }
}

Reglas:
- NO incluyas el texto completo corregido.
- NO uses markdown, NO incluyas ```json.
- El JSON debe empezar con { y terminar con }.
"""

resultados = []

for i, texto in enumerate(textos, start=1):
    print(f"Procesando texto {i}/{len(textos)}...")

    messages = [
        {"role": "system", "content": prompt_literal},
        {"role": "user", "content": texto}
    ]

    try:
        response = client.chat.completions.create(
            model=DEPLOYMENT_GPT,
            messages=messages,
            temperature=0,
            response_format={"type": "json_object"}
        )

        respuesta_limpia = response.choices[0].message.content.strip()
        resultado_json = json.loads(respuesta_limpia)
        resultados.append({
            "id_texto": i,
            "resultado": resultado_json
        })

    except json.JSONDecodeError as e:
        print(f"Error al parsear JSON en texto {i}: {e}")
        print("Respuesta cruda recibida:")
        print(respuesta_limpia)

output_path = os.path.join("correcciones_selectas", "literal.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(resultados, f, ensure_ascii=False, indent=4)

print(f"\nTodos los resultados guardados en {output_path}")
# Out:
# Procesando texto 1/10...
# Procesando texto 2/10...
# Procesando texto 3/10...
# Procesando texto 4/10...
# Procesando texto 5/10...
# Procesando texto 6/10...
# Procesando texto 7/10...
# Procesando texto 8/10...
# Procesando texto 9/10...
# Procesando texto 10/10...
#
# Todos los resultados guardados en correcciones_selectas\literal.json

# %% [markdown]
# # ORTOGRAFÍA PUNTUAL

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()
API_KEY = os.getenv("AZURE_OPENAI_KEY")
ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
DEPLOYMENT_GPT = os.getenv("AZURE_OPENAI_DEPLOYMENT_GPT")
API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

client = AzureOpenAI(
    api_key=API_KEY,
    api_version=API_VERSION,
    azure_endpoint=ENDPOINT
)

df = pd.read_excel("escritos_seleccionados_ort.xlsx")
textos = df["escrito"].dropna().tolist() 

prompt_puntual = """
Eres un asistente experto en corrección de textos. 

Tu tarea es corregir ÚNICAMENTE errores relacionados con signos de puntuación, de acuerdo con las normas de la RAE:

- Uso de la coma.
- Uso del punto (seguido, aparte y final).
- Uso del punto y coma.
- Uso de signos de exclamación e interrogación.

INSTRUCCIONES CRÍTICAS:
- NO revises ni corrijas tildes (acentos ortográficos). 
- NO corrijas errores de ortografía literal (letras omitidas, añadidas, sustituidas, mayúsculas, etc.).
- NO evalúes vocabulario ni estilo.
- Si un posible “error” solo se diferencia de la forma correcta por la presencia o ausencia de una tilde, DEBES IGNORARLO.

Formato de salida (solo JSON válido):

{
  "errores_ortografia_puntual": {
        "error_1": ["error → corrección"],
        "error_2": ["error → corrección"],
        ...
  }
}

Reglas:
- Cada error y corrección debe mostrarse con el fragmento MÁS BREVE posible que contenga el error (no más de 20 caracteres).
- NO incluyas el texto completo corregido.
- Devuelve SOLO JSON válido, sin markdown ni ```json.
- El JSON debe comenzar con { y terminar con }.
"""

resultados = []

for i, texto in enumerate(textos, start=1):
    print(f"Procesando texto {i}/{len(textos)}...")

    messages = [
        {"role": "system", "content": prompt_puntual},
        {"role": "user", "content": texto}
    ]

    try:
        response = client.chat.completions.create(
            model=DEPLOYMENT_GPT,
            messages=messages,
            temperature=0,
            response_format={"type": "json_object"}
        )

        respuesta_limpia = response.choices[0].message.content.strip()
        resultado_json = json.loads(respuesta_limpia)
        resultados.append({
            "id_texto": i,
            "resultado": resultado_json
        })

    except json.JSONDecodeError as e:
        print(f"Error al parsear JSON en texto {i}: {e}")
        print("Respuesta cruda recibida:")
        print(respuesta_limpia)

output_path = os.path.join("correcciones_selectas", "puntual.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(resultados, f, ensure_ascii=False, indent=4)

print(f"\nTodos los resultados guardados en {output_path}")
# Out:
# Procesando texto 1/10...
# Procesando texto 2/10...
# Procesando texto 3/10...
# Procesando texto 4/10...
# Procesando texto 5/10...
# Procesando texto 6/10...
# Procesando texto 7/10...
# Procesando texto 8/10...
# Procesando texto 9/10...
# Procesando texto 10/10...
#
# Todos los resultados guardados en correcciones_selectas\puntual.json

# %% [markdown]
# # VOCABULARIO: AMPLITUD

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()
API_KEY = os.getenv("AZURE_OPENAI_KEY")
ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
DEPLOYMENT_GPT = os.getenv("AZURE_OPENAI_DEPLOYMENT_GPT")
API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

client = AzureOpenAI(
    api_key=API_KEY,
    api_version=API_VERSION,
    azure_endpoint=ENDPOINT
)

df = pd.read_excel("escritos_seleccionados_ort.xlsx")
textos = df["escrito"].dropna().tolist() 


prompt_amplitud = """
Eres un asistente experto en corrección de textos.

Analiza EXCLUSIVAMENTE la dimensión de AMPLITUD DE VOCABULARIO en un único PÁRRAFO recibido, según las siguientes reglas:

- El emisor debe usar sinónimos y correferencias para evitar repeticiones innecesarias.
- Se sanciona la repetición de una misma palabra dentro de un mismo párrafo.
- EXCEPCIÓN: No sancionar repeticiones cuando se trate de una figura retórica de énfasis.
- Solo contabilizar repeticiones en SUSTANTIVOS, ADJETIVOS, VERBOS y ADVERBIOS.
- No contar conjugaciones verbales ni perífrasis verbales (auxiliar + infinitivo/gerundio/participio).
- Se analiza únicamente el párrafo entregado.

Tu respuesta debe seguir esta estructura:

{
  "errores_vocabulario_amplitud": {
        "palabra1": ["n veces"],
        "palabra2": ["n veces"]
  }
}

INSTRUCCIONES PARA EL FORMATO:
- Devuelve SOLO palabras repetidas con su número de apariciones.
- NO incluyas texto corregido ni el párrafo original.
- NO uses markdown, NO incluyas ```json, devuelve SOLO el JSON.
"""

resultados = []

for i, texto in enumerate(textos, start=1):
    print(f"Procesando texto {i}/{len(textos)}...")

    parrafos = [p.strip() for p in texto.split("\n") if p.strip()]  

    errores_por_texto = {"id_texto": i, "errores_vocabulario_amplitud": {}}

    for j, parrafo in enumerate(parrafos, start=1):
        messages = [
            {"role": "system", "content": prompt_amplitud},
            {"role": "user", "content": parrafo}
        ]

        try:
            response = client.chat.completions.create(
                model=DEPLOYMENT_GPT,
                messages=messages,
                temperature=0,
                response_format={"type": "json_object"}
            )

            respuesta_limpia = response.choices[0].message.content.strip()
            resultado_json = json.loads(respuesta_limpia)

            errores_por_texto["errores_vocabulario_amplitud"][f"parrafo_{j}"] = resultado_json.get("errores_vocabulario_amplitud", {})

        except json.JSONDecodeError as e:
            print(f"Error al parsear JSON en texto {i}, párrafo {j}: {e}")
            print("Respuesta cruda recibida:")
            print(respuesta_limpia)

    resultados.append(errores_por_texto)

output_path = os.path.join("correcciones_selectas", "amplitud.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(resultados, f, ensure_ascii=False, indent=4)

print(f"\nTodos los resultados guardados en {output_path}")
# Out:
# Procesando texto 1/10...
# Procesando texto 2/10...
# Procesando texto 3/10...
# Procesando texto 4/10...
# Procesando texto 5/10...
# Procesando texto 6/10...
# Procesando texto 7/10...
# Procesando texto 8/10...
# Procesando texto 9/10...
# Procesando texto 10/10...
#
# Todos los resultados guardados en correcciones_selectas\amplitud.json

# %% [markdown]
# # VOCABULARIO PRECISIÓN LÉXICA

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()
API_KEY = os.getenv("AZURE_OPENAI_KEY")
ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
DEPLOYMENT_GPT = os.getenv("AZURE_OPENAI_DEPLOYMENT_GPT")
API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

client = AzureOpenAI(
    api_key=API_KEY,
    api_version=API_VERSION,
    azure_endpoint=ENDPOINT
)

df = pd.read_excel("escritos_seleccionados_ort.xlsx")
textos = df["escrito"].dropna().tolist() 

prompt_precision = """
Eres un asistente experto en corrección de textos.

Analiza EXCLUSIVAMENTE la dimensión de PRECISIÓN LÉXICA, según los siguientes criterios:

A) USO INCORRECTO DE SIGNIFICADOS:
- Detecta palabras usadas con un significado equivocado que cambien el sentido del texto.
- Ejemplo: “absceso” por “acceso”, “actitud” por “aptitud”.

B) EXTRANJERISMOS:
- Señala extranjerismos que NO estén en comillas, cursiva o introducidos explícitamente por el autor.
- Ejemplo incorrecto: usar "online" sin comillas ni contexto en vez de “en línea”.
- No sanciones extranjerismos correctos o presentados como citas.

C) REDUNDANCIAS:
- Detecta repeticiones innecesarias de palabras o ideas.
- Ejemplo: “salir para afuera”, “volar por los aires”, “hace un tiempo atrás”.

Tu respuesta debe seguir esta estructura:

{
  "errores_precision": {
        "error_1": ["error → corrección", CRITERIO],
        "error_2": ["error → corrección", CRITERIO],
        ...,
        "error_n": ["error → corrección", CRITERIO]
  }
}

REGLAS:
- En CRITERIO indica "USO INCORRECTO DE SIGNIFICADOS", "EXTRANJERISMO" o "REDUNDANCIA".
- Enumera todos los errores encontrados bajo la clave "errores_vocabulario_precision".
- En cada caso, muestra el fragmento MÁS BREVE posible con el error.
- Da una corrección propuesta o explica por qué es impreciso.
- NO incluyas el texto completo corregido.
- NO uses markdown, NO incluyas ```json, devuelve SOLO el JSON.
"""

resultados = []

for i, texto in enumerate(textos, start=1):
    print(f"Procesando texto {i}/{len(textos)}...")

    messages = [
        {"role": "system", "content": prompt_precision},
        {"role": "user", "content": texto}
    ]

    try:
        response = client.chat.completions.create(
            model=DEPLOYMENT_GPT,
            messages=messages,
            temperature=0,
            response_format={"type": "json_object"}
        )

        respuesta_limpia = response.choices[0].message.content.strip()
        resultado_json = json.loads(respuesta_limpia)
        resultados.append({
            "id_texto": i,
            "resultado": resultado_json
        })

    except json.JSONDecodeError as e:
        print(f"Error al parsear JSON en texto {i}: {e}")
        print("Respuesta cruda recibida:")
        print(respuesta_limpia)

output_path = os.path.join("correcciones_selectas", "precision.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(resultados, f, ensure_ascii=False, indent=4)

print(f"\nTodos los resultados guardados en {output_path}")
# Out:
# Procesando texto 1/10...
# Procesando texto 2/10...
# Procesando texto 3/10...
# Procesando texto 4/10...
# Procesando texto 5/10...
# Procesando texto 6/10...
# Procesando texto 7/10...
# Procesando texto 8/10...
# Procesando texto 9/10...
# Procesando texto 10/10...
#
# Todos los resultados guardados en correcciones_selectas\precision.json

# %% [markdown]
# # VOCABULARIO REGISTRO FORMAL

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()
API_KEY = os.getenv("AZURE_OPENAI_KEY")
ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
DEPLOYMENT_GPT = os.getenv("AZURE_OPENAI_DEPLOYMENT_GPT")
API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

client = AzureOpenAI(
    api_key=API_KEY,
    api_version=API_VERSION,
    azure_endpoint=ENDPOINT
)

df = pd.read_excel("escritos_seleccionados_ort.xlsx")
textos = df["escrito"].dropna().tolist() 

prompt_formal = """
Eres un asistente experto en corrección de textos.

Analiza EXCLUSIVAMENTE la dimensión de VOCABULARIO DE ADECUACIÓN AL REGISTRO DE HABLA FORMAL, según los siguientes criterios:

1) SEGUNDA PERSONA SINGULAR:
- Detecta uso del pronombre “tú” o verbos conjugados en segunda persona singular.
- Ejemplo: "Cuando postulas a un trabajo, tú tienes que pasar una entrevista".

2) ABREVIACIONES:
- Señala formas abreviadas propias de la oralidad.
- Ejemplo: “profe” por “profesor/a”, “finde” por “fin de semana”.

3) COLOQUIALISMOS: uso de expresiones coloquiales (expresiones propias de la conversación informal); por ejemplo: “socio” por “amigo”, “cachar” por “comprender” o “darse cuenta”, “pega” por “trabajo”; el uso de calificativos más expresivos: “mina” por “guapa”, “bacán” por “excelente”, “pichiruche” por “insignificante”; el uso de diminutivos y el prefijo “super” para amplificar valor.

4) ESCRITURA DE PALABRAS CON SÍMBOLOS O CARACTERES NO GRAFEMATICOS: sustitución de letras por símbolos para representar palabras (ejemplo: "q’" por "que", "total%" por "totalmente", "publicaØ" por "publicación").

Tu respuesta debe seguir esta estructura:

{
  "errores_vocabulario_formal": {
        "error_1": ["error → corrección sugerida", CRITERIO],
        "error_2": ["error → corrección sugerida"], CRITERIO],
        ...,
        "error_n": ["error → corrección sugerida", CRITERIO]
  }
}

REGLAS:
- En "CRITERIO", indica si el criterio es "SEGUNDA PERSONA SINGULAR", "ABREVIACIONES", "COLOQUIALISMOS" o "CÓDIGO ESCRITO NO FORMAL".
- Enumera todos los errores encontrados bajo la clave "errores_vocabulario_formal".
- En cada caso, muestra el fragmento MÁS BREVE posible con el error.
- Ofrece una corrección sugerida acorde al registro formal.
- NO incluyas el texto completo corregido.
- NO uses markdown, NO incluyas ```json, devuelve SOLO el JSON.
- NO INCLUYAS ERRORES DE ORTOGRFÍA ACENTUAL LITERAL NI PUNTUAL.
"""

resultados = []

for i, texto in enumerate(textos, start=1):
    print(f"Procesando texto {i}/{len(textos)}...")

    messages = [
        {"role": "system", "content": prompt_formal},
        {"role": "user", "content": texto}
    ]

    try:
        response = client.chat.completions.create(
            model=DEPLOYMENT_GPT,
            messages=messages,
            temperature=0,
            response_format={"type": "json_object"}
        )

        respuesta_limpia = response.choices[0].message.content.strip()
        resultado_json = json.loads(respuesta_limpia)
        resultados.append({
            "id_texto": i,
            "resultado": resultado_json
        })

    except json.JSONDecodeError as e:
        print(f"Error al parsear JSON en texto {i}: {e}")
        print("Respuesta cruda recibida:")
        print(respuesta_limpia)

output_path = os.path.join("correcciones_selectas", "formal.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(resultados, f, ensure_ascii=False, indent=4)

print(f"\nTodos los resultados guardados en {output_path}")

# 4) CÓDIGO ESCRITO NO FORMAL:
# - Detecta usos innecesarios de caracteres o símbolos en el español, sin incluiir til
# que alteren la escritura formal con símbolos o caracteres que no son letras ni tildes.
# - Ejemplos: "q’" por "que", "total%" por "totalmente", "publicaØ" por "publicación".
# Out:
# Procesando texto 1/10...
# Procesando texto 2/10...
# Procesando texto 3/10...
# Procesando texto 4/10...
# Procesando texto 5/10...
# Procesando texto 6/10...
# Procesando texto 7/10...
# Error al parsear JSON en texto 7: Unterminated string starting at: line 747 column 9 (char 47567)
# Respuesta cruda recibida:
# {
#   "errores_vocabulario_formal": {
#         "error_1": ["quiero que → deseo que", "COLOQUIALISMOS"],
#         "error_2": ["creo que → considero que", "COLOQUIALISMOS"],
#         "error_3": ["nos rodean → nos circundan", "COLOQUIALISMOS"],
#         "error_4": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_5": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_6": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_7": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_8": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_9": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_10": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_11": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_12": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_13": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_14": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_15": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_16": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_17": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_18": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_19": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_20": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_21": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_22": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_23": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_24": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_25": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_26": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_27": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_28": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_29": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_30": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_31": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_32": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_33": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_34": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_35": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_36": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_37": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_38": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_39": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_40": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_41": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_42": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_43": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_44": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_45": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_46": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_47": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_48": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_49": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_50": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_51": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_52": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_53": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_54": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_55": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_56": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_57": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_58": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_59": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_60": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_61": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_62": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_63": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_64": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_65": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_66": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_67": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_68": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_69": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_70": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_71": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_72": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_73": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_74": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_75": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_76": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_77": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_78": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_79": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_80": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_81": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_82": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_83": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_84": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_85": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_86": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_87": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_88": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_89": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_90": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_91": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_92": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_93": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_94": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_95": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_96": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_97": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_98": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_99": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_100": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_101": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_102": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_103": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_104": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_105": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_106": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_107": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_108": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_109": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_110": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_111": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_112": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_113": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_114": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_115": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_116": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_117": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_118": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_119": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_120": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_121": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_122": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_123": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_124": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_125": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_126": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_127": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_128": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_129": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_130": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_131": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_132": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_133": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_134": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_135": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_136": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_137": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_138": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_139": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_140": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_141": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_142": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_143": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_144": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_145": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_146": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_147": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_148": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_149": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_150": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_151": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_152": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_153": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_154": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_155": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_156": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_157": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_158": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_159": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_160": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_161": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_162": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_163": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_164": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_165": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_166": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_167": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_168": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_169": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_170": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_171": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_172": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_173": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_174": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_175": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_176": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_177": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_178": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_179": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_180": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_181": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_182": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_183": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_184": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_185": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_186": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_187": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_188": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_189": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_190": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_191": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_192": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_193": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_194": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_195": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_196": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_197": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_198": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_199": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_200": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_201": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_202": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_203": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_204": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_205": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_206": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_207": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_208": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_209": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_210": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_211": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_212": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_213": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_214": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_215": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_216": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_217": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_218": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_219": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_220": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_221": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_222": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_223": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_224": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_225": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_226": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_227": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_228": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_229": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_230": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_231": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_232": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_233": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_234": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_235": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_236": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_237": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_238": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_239": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_240": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_241": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_242": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_243": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_244": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_245": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_246": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_247": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_248": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_249": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_250": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_251": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_252": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_253": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_254": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_255": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_256": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_257": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_258": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_259": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_260": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_261": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_262": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_263": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_264": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_265": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_266": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_267": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_268": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_269": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_270": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_271": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_272": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_273": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_274": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_275": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_276": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_277": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_278": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_279": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_280": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_281": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_282": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_283": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_284": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_285": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_286": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_287": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_288": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_289": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_290": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_291": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_292": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_293": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_294": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_295": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_296": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_297": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_298": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_299": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_300": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_301": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_302": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_303": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_304": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_305": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_306": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_307": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_308": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_309": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_310": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_311": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_312": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_313": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_314": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_315": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_316": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_317": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_318": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_319": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_320": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_321": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_322": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_323": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_324": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_325": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_326": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_327": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_328": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_329": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_330": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_331": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_332": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_333": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_334": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_335": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_336": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_337": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_338": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_339": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_340": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_341": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_342": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_343": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_344": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_345": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_346": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_347": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_348": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_349": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_350": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_351": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_352": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_353": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_354": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_355": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_356": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_357": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_358": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_359": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_360": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_361": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_362": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_363": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_364": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_365": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_366": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_367": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_368": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_369": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_370": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_371": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_372": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_373": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_374": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_375": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_376": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_377": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_378": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_379": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_380": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_381": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_382": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_383": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_384": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_385": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_386": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_387": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_388": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_389": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_390": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_391": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_392": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_393": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_394": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_395": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_396": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_397": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_398": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_399": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_400": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_401": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_402": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_403": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_404": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_405": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_406": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_407": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_408": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_409": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_410": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_411": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_412": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_413": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_414": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_415": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_416": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_417": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_418": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_419": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_420": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_421": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_422": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_423": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_424": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_425": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_426": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_427": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_428": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_429": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_430": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_431": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_432": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_433": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_434": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_435": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_436": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_437": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_438": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_439": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_440": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_441": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_442": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_443": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_444": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_445": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_446": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_447": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_448": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_449": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_450": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_451": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_452": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_453": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_454": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_455": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_456": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_457": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_458": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_459": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_460": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_461": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_462": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_463": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_464": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_465": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_466": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_467": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_468": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_469": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_470": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_471": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_472": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_473": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_474": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_475": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_476": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_477": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_478": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_479": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_480": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_481": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_482": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_483": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_484": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_485": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_486": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_487": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_488": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_489": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_490": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_491": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_492": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_493": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_494": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_495": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_496": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_497": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_498": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_499": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_500": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_501": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_502": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_503": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_504": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_505": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_506": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_507": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_508": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_509": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_510": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_511": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_512": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_513": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_514": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_515": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_516": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_517": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_518": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_519": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_520": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_521": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_522": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_523": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_524": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_525": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_526": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_527": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_528": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_529": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_530": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_531": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_532": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_533": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_534": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_535": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_536": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_537": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_538": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_539": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_540": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_541": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_542": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_543": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_544": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_545": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_546": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_547": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_548": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_549": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_550": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_551": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_552": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_553": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_554": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_555": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_556": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_557": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_558": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_559": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_560": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_561": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_562": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_563": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_564": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_565": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_566": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_567": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_568": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_569": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_570": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_571": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_572": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_573": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_574": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_575": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_576": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_577": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_578": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_579": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_580": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_581": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_582": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_583": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_584": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_585": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_586": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_587": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_588": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_589": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_590": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_591": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_592": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_593": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_594": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_595": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_596": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_597": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_598": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_599": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_600": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_601": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_602": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_603": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_604": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_605": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_606": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_607": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_608": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_609": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_610": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_611": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_612": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_613": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_614": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_615": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_616": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_617": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_618": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_619": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_620": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_621": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_622": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_623": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_624": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_625": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_626": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_627": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_628": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_629": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_630": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_631": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_632": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_633": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_634": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_635": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_636": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_637": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_638": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_639": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_640": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_641": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_642": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_643": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_644": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_645": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_646": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_647": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_648": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_649": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_650": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_651": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_652": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_653": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_654": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_655": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_656": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_657": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_658": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_659": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_660": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_661": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_662": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_663": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_664": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_665": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_666": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_667": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_668": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_669": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_670": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_671": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_672": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_673": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_674": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_675": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_676": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_677": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_678": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_679": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_680": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_681": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_682": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_683": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_684": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_685": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_686": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_687": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_688": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_689": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_690": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_691": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_692": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_693": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_694": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_695": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_696": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_697": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_698": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_699": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_700": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_701": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_702": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_703": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_704": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_705": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_706": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_707": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_708": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_709": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_710": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_711": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_712": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_713": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_714": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_715": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_716": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_717": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_718": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_719": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_720": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_721": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_722": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_723": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_724": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_725": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_726": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_727": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_728": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_729": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_730": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_731": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_732": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_733": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_734": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_735": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_736": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_737": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_738": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_739": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_740": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_741": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_742": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_743": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_744": ["sino que → sino que", "COLOQUIALISMOS"],
#         "error_
# Procesando texto 8/10...
# Procesando texto 9/10...
# Procesando texto 10/10...
#
# Todos los resultados guardados en correcciones_selectas\formal.json

# %% [markdown]
# # COHESIÓN TEXTUAL CONCORDANCIA GRAMATICAL

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()
API_KEY = os.getenv("AZURE_OPENAI_KEY")
ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
DEPLOYMENT_GPT = os.getenv("AZURE_OPENAI_DEPLOYMENT_GPT")
API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

client = AzureOpenAI(
    api_key=API_KEY,
    api_version=API_VERSION,
    azure_endpoint=ENDPOINT
)

df = pd.read_excel("escritos_seleccionados_ort.xlsx")
textos = df["escrito"].dropna().tolist() 

prompt_concordancia = """
Eres un asistente experto en corrección de textos.  

Analiza EXCLUSIVAMENTE la dimensión de **COHESIÓN TEXTUAL: CONCORDANCIA GRAMATICAL**, según estas reglas:  

Se consideran errores de concordancia:
- Falta de concordancia entre **sustantivo y adjetivo**.  
- Falta de concordancia entre **sujeto y predicado**.  
- Falta de concordancia entre **pronombres relativos y sus antecedentes**.  
- Falta de consistencia en el uso de **tiempos verbales**, SOLO en los siguientes casos:  
  A) Cambio de tiempo verbal en una enumeración de acciones.  
  B) Uso de tiempos no adecuados en cláusulas condicionales y concesivas.  

Tu respuesta debe seguir esta estructura:  

{
  "errores_cohesion_concordancia": {
    "error_1": ["error → corrección", "tipo: sustantivo-adjetivo"],
    "error_2": ["error → corrección", "tipo: sujeto-predicado"],
    "error_3": ["error → corrección", "tipo: pronombre-relativo"],
    "error_4": ["error → corrección", "tipo: A"],
    "error_5": ["error → corrección", "tipo: B"],
    ...
    "error_n": ["error → corrección", "tipo: ..."]
  }
}

REGLAS:  
- En "errores_cohesion_concordancia" lista todos los errores detectados.  
- Cada error debe mostrarse con el fragmento MÁS BREVE posible (no frases completas).  
- Especifica en cada caso el tipo de error:  
  - "sustantivo-adjetivo"  
  - "sujeto-predicado"  
  - "pronombre-relativo"  
  - "A" (enumeración de acciones)  
  - "B" (cláusulas condicionales o concesivas)  
- NO incluyas el texto completo corregido.  
- NO uses markdown, NO incluyas ```json, devuelve SOLO el JSON.  
"""

resultados = []

for i, texto in enumerate(textos, start=1):
    print(f"Procesando texto {i}/{len(textos)}...")

    messages = [
        {"role": "system", "content": prompt_concordancia},
        {"role": "user", "content": texto}
    ]

    try:
        response = client.chat.completions.create(
            model=DEPLOYMENT_GPT,
            messages=messages,
            temperature=0,
            response_format={"type": "json_object"}
        )

        respuesta_limpia = response.choices[0].message.content.strip()
        resultado_json = json.loads(respuesta_limpia)
        resultados.append({
            "id_texto": i,
            "resultado": resultado_json
        })

    except json.JSONDecodeError as e:
        print(f"Error al parsear JSON en texto {i}: {e}")
        print("Respuesta cruda recibida:")
        print(respuesta_limpia)

output_path = os.path.join("correcciones_selectas", "concordancia.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(resultados, f, ensure_ascii=False, indent=4)

print(f"\nTodos los resultados guardados en {output_path}")
# Out:
# Procesando texto 1/10...
# Procesando texto 2/10...
# Procesando texto 3/10...
# Procesando texto 4/10...
# Procesando texto 5/10...
# Procesando texto 6/10...
# Procesando texto 7/10...
# Procesando texto 8/10...
# Procesando texto 9/10...
# Procesando texto 10/10...
#
# Todos los resultados guardados en correcciones_selectas\concordancia.json

# %% [markdown]
# # COHESIÓN TEXTUAL CONEXIÓN TEXTUAL

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()
API_KEY = os.getenv("AZURE_OPENAI_KEY")
ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
DEPLOYMENT_GPT = os.getenv("AZURE_OPENAI_DEPLOYMENT_GPT")
API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

client = AzureOpenAI(
    api_key=API_KEY,
    api_version=API_VERSION,
    azure_endpoint=ENDPOINT
)

df = pd.read_excel("escritos_seleccionados_ort.xlsx")
textos = df["escrito"].dropna().tolist() 

prompt_conexion = """
Eres un asistente experto en corrección de textos.  

Analiza EXCLUSIVAMENTE la dimensión de **COHESIÓN TEXTUAL: CONEXIÓN TEXTUAL**, según estas reglas:  

Se consideran errores de conexión textual:  
1. Uso inadecuado de preposiciones o rección: falta la preposición o se usa una preposición incorrecta.  
   - Incluye queísmo (uso de "que" sin "de" cuando corresponde) y dequeísmo (uso de "de que" cuando solo corresponde "que").  
2. Uso inadecuado de locuciones preposicionales u otras construcciones lexicales de carácter conectivo (ej.: "sobre la base de", "a razón de", "en relación con") **cuando afecten la lógica de conexión oracional y/o textual**.  
3. Ausencia de conectores o uso de conectores inadecuados para expresar la idea que se busca; mal uso de organizadores textuales (ej.: "en primer lugar", "por un lado", etc.).  

Tu respuesta debe seguir esta estructura:  

{
  "errores_cohesion_conexion": {
    "error_1": ["error → corrección", "tipo: preposición/rección"],
    "error_2": ["error → corrección", "tipo: queísmo"],
    "error_3": ["error → corrección", "tipo: dequeísmo"],
    "error_4": ["error → corrección", "tipo: locución-preposicional"],
    "error_5": ["error → corrección", "tipo: conector-ausente"],
    "error_6": ["error → corrección", "tipo: conector-inadecuado"],
    ...
    "error_n": ["error → corrección", "tipo: ..."]
  }
}

REGLAS:  
- En "errores_cohesion_conexion" lista todos los errores detectados.  
- Cada error debe mostrarse con el fragmento MÁS BREVE posible (no frases completas).  
- Especifica siempre el tipo de error con una de estas categorías:  
  - "preposición/rección"  
  - "queísmo"  
  - "dequeísmo"  
  - "locución-preposicional"  
  - "conector-ausente"  
  - "conector-inadecuado"  
- NO incluyas el texto completo corregido.  
- NO uses markdown, NO incluyas ```json, devuelve SOLO el JSON.  
- NO INCLUYAS ERRORES DE ORTOGRFÍA ACENTUAL LITERAL NI PUNTUAL.
"""

resultados = []

for i, texto in enumerate(textos, start=1):
    print(f"Procesando texto {i}/{len(textos)}...")

    messages = [
        {"role": "system", "content": prompt_conexion},
        {"role": "user", "content": texto}
    ]

    try:
        response = client.chat.completions.create(
            model=DEPLOYMENT_GPT,
            messages=messages,
            temperature=0,
            response_format={"type": "json_object"}
        )

        respuesta_limpia = response.choices[0].message.content.strip()
        resultado_json = json.loads(respuesta_limpia)
        resultados.append({
            "id_texto": i,
            "resultado": resultado_json
        })

    except json.JSONDecodeError as e:
        print(f"Error al parsear JSON en texto {i}: {e}")
        print("Respuesta cruda recibida:")
        print(respuesta_limpia)

output_path = os.path.join("correcciones_selectas", "conexion.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(resultados, f, ensure_ascii=False, indent=4)

print(f"\nTodos los resultados guardados en {output_path}")
# Out:
# Procesando texto 1/10...
# Procesando texto 2/10...
# Procesando texto 3/10...
# Procesando texto 4/10...
# Procesando texto 5/10...
# Procesando texto 6/10...
# Procesando texto 7/10...
# Procesando texto 8/10...
# Procesando texto 9/10...
# Procesando texto 10/10...
#
# Todos los resultados guardados en correcciones_selectas\conexion.json

# %% [markdown]
# # COHESIÓN TEXTUAL: REFERENCIAS Y CORREFERENCIAS

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()
API_KEY = os.getenv("AZURE_OPENAI_KEY")
ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
DEPLOYMENT_GPT = os.getenv("AZURE_OPENAI_DEPLOYMENT_GPT")
API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

client = AzureOpenAI(
    api_key=API_KEY,
    api_version=API_VERSION,
    azure_endpoint=ENDPOINT
)

df = pd.read_excel("escritos_seleccionados_ort.xlsx")
textos = df["escrito"].dropna().tolist() 

prompt_referencias = """
Eres un asistente experto en corrección de textos.  

Analiza EXCLUSIVAMENTE la dimensión de **COHESIÓN TEXTUAL: REFERENCIAS Y CORREFERENCIAS**, según estas reglas:  

Se consideran errores de referencia y correferencia:  
- Pronombres o mecanismos de correferencia que no tengan un referente claro en el texto (ej.: "esto", "lo anterior", "esa situación").  

Tu respuesta debe seguir esta estructura:  

{
  "errores_cohesion_referencia": {
    "error_1": ["error → corrección", "tipo: pronombre-sin-referencia"],
    "error_2": ["error → corrección", "tipo: pronombre-sin-referencia"],
    ...
    "error_n": ["error → corrección", "tipo: pronombre-sin-referencia"]
  }
}

REGLAS:  
- En "errores_cohesion_referencia" lista todos los errores detectados.  
- Cada error debe mostrarse con el fragmento MÁS BREVE posible que contenga el error (no frases completas).  
- Todos los errores se clasifican como "tipo: pronombre-sin-referencia".  
- NO incluyas el texto completo corregido.  
- NO uses markdown, NO incluyas ```json, devuelve SOLO el JSON. 
"""

resultados = []

for i, texto in enumerate(textos, start=1):
    print(f"Procesando texto {i}/{len(textos)}...")

    messages = [
        {"role": "system", "content": prompt_referencias},
        {"role": "user", "content": texto}
    ]

    try:
        response = client.chat.completions.create(
            model=DEPLOYMENT_GPT,
            messages=messages,
            temperature=0,
            response_format={"type": "json_object"}
        )

        respuesta_limpia = response.choices[0].message.content.strip()
        resultado_json = json.loads(respuesta_limpia)
        resultados.append({
            "id_texto": i,
            "resultado": resultado_json
        })

    except json.JSONDecodeError as e:
        print(f"Error al parsear JSON en texto {i}: {e}")
        print("Respuesta cruda recibida:")
        print(respuesta_limpia)

output_path = os.path.join("correcciones_selectas", "referencias.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(resultados, f, ensure_ascii=False, indent=4)

print(f"\nTodos los resultados guardados en {output_path}")
# Out:
# Procesando texto 1/10...
# Procesando texto 2/10...
# Procesando texto 3/10...
# Procesando texto 4/10...
# Procesando texto 5/10...
# Procesando texto 6/10...
# Procesando texto 7/10...
# Procesando texto 8/10...
# Procesando texto 9/10...
# Procesando texto 10/10...
#
# Todos los resultados guardados en correcciones_selectas\referencias.json
